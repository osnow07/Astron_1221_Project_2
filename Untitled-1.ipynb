# %%
from astropy.io import fits
path_image_1 = "/home/wesley/Desktop/Astron_1221_Project_2/strange 2/MAST_2026-03-11T1816/JWST/"

hdu_1 = fits.open((path_image_1 + 'jw01027004001_02101_00001_mirimage_cal.fits'))[0]

# %%
hdu_1.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# DATE    = '2025-12-23T12:23:50.606' / UTC date file created
# ORIGIN  = 'STSCI   '           / Organization responsible for creating file
# TIMESYS = 'UTC     '           / principal time system for time-related keywords
# TIMEUNIT= 's       '           / Default unit applicable to all time values
# FILENAME= 'jw01027004001_02101_00001_mirimage_cal.fits' / Name of the file
# SDP_VER = '2025_4a '           / Data Processing (DP) Software Version
# PRD_VER = 'PRDOPSSOC-072'      / S&OC Project Reference Database (PRD) Version
# OSS_VER = '8.4.4   '           / Observatory Scheduling Software (OSS) Version
# GSC_VER = 'GSC31   '           / Guide Star Catalog (GSC) Version
# CAL_VER = '1.20.2  '           / Calibration Software Version
# ...

# %%
#creates image of full outflows
fig, ax = plt.subplots(1, 1, figsize=(16, 9), subplot_kw={'projection': WCS(hdu_1)})
ax.imshow(im_1.data-np.median(im_1.data), origin='lower',vmin=-15, vmax=150, cmap='viridis', interpolation='none')
zoom = 350
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #creates image of full outflows
# ----> 2 fig, ax = plt.subplots(1, 1, figsize=(16, 9), subplot_kw={'projection': WCS(hdu_1)})
#       3 ax.imshow(im_1.data-np.median(im_1.data), origin='lower',vmin=-15, vmax=150, cmap='viridis', interpolation='none')
#       4 zoom = 350
#
# NameError: name 'plt' is not defined
